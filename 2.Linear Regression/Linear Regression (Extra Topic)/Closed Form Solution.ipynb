# %% [markdown]
# #### Closed Form Solution in Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_regression

# %%
# Generate Dataset
X,Y = make_regression(n_samples=400,n_features=1,n_informative=1,noise=1.8,random_state=11)

# Here Y is a vector so we convert it into a matrix 
# as we used During The derivation
Y = Y.reshape((-1,1))
print(X.shape)
print(Y.shape)
# Out:
# (400, 1)
# (400, 1)

# %%
# Normalize
plt.style.use("seaborn")
X = (X-X.mean())/X.std()

# Visualize
plt.figure()
plt.scatter(X,Y)
plt.title("Normalized Data")
plt.show()

# %%
#Append Ones to our X MAtrix
ones = np.ones((X.shape[0],1))
X_ = np.hstack((X,ones))
print(X_.shape)
print(X_[:5,:])
# Out:
# (400, 2)
# [[-0.86881353  1.        ]
#  [ 1.04796658  1.        ]
#  [-0.2019676   1.        ]
#  [-0.34017061  1.        ]
#  [ 0.13317349  1.        ]]

# %%
def predict(X,theta):
    return np.dot(X,theta)

def getThetaClosedForm(X,Y):
    
    #Convert Y as a Matrix 
    Y = np.mat(Y)
    firstPart = np.dot(X.T,X)
    secondPart = np.dot(X.T,Y)
    
    #To calculate the inverse of first part
    theta = np.linalg.pinv(firstPart)*secondPart
    return theta

# %%
theta = getThetaClosedForm(X_,Y)
print(theta)
# Out:
# [[19.45877082]
#  [-0.29187892]]

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X,predict(X_,theta),color='red',label="prediction")
plt.title("Normalized Data")
plt.legend()
plt.show()

# %%
pred=predict(X_,theta)

# %%
print(pred)
# Out:
# [[-17.19792227]
#  [ 20.10026252]
#  [ -4.22192017]
#  [ -6.91118091]
#  [  2.29951351]
#  [ 25.69695168]
#  [  6.14556925]
#  [ 14.40317204]
#  [ -3.58453494]
#  [  7.24466673]
#  [-16.12600559]
#  [-41.39048769]
#  [  8.67182935]
#  [ -3.42990868]
#  [ 22.92586205]
#  [ -2.74923055]
#  [ 23.05633595]
#  [ -9.64402297]
#  [ 24.98482242]
#  [ 11.72797046]
#  [-26.02383693]
#  [-19.97232308]
#  [ -9.81058504]
#  [-17.77104554]
#  [-30.9991651 ]
#  [ -7.24845892]
#  [ -2.05300436]
#  [ 25.70557394]
#  [-26.67291112]
#  [ -5.15741946]
#  [ 25.65570743]
#  [-20.33403879]
#  [-17.49571357]
#  [ -1.4951679 ]
#  [ -3.42044283]
#  [ 13.54657024]
#  [ 14.33039973]
#  [ -3.49949829]
#  [-39.90922016]
#  [-31.85000795]
#  [  9.87879471]
#  [  9.92771396]
#  [-16.68940286]
#  [ -9.6344292 ]
#  [-14.61210126]
#  [ 10.06961483]
#  [ 43.77276551]
#  [ -1.27504431]
#  [-24.08616573]
#  [-22.7679075 ]
#  [ 12.95961827]
#  [  3.38185376]
#  [ 29.55331641]
#  [ 17.38934904]
#  [ 29.62337907]
# ...
