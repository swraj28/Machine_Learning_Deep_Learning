# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn")

dfx = pd.read_csv('../../Datasets/Locally Weighted Regression/weightedX.csv')
dfy = pd.read_csv('../../Datasets/Locally Weighted Regression/weightedY.csv')

x = dfx.values
y = dfy.values

x = x.reshape((-1,))
y = y.reshape((-1,))

X = (x-x.mean())/x.std()
Y = y

# %%
x1 = X 
x2 = X**2

X = np.stack((x1,x2),axis=1)
print(X.shape)
print(Y.shape)
# Out:
# (99, 2)
# (99,)

# %%
plt.scatter(X[:,0],Y)
plt.show()
plt.scatter(X[:,1],Y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [markdown]
# ## Training

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# # Predictions

# %%
output = model.predict(X)

# %%
# Parameters Learnedm

# %%
bias = model.intercept_
coeff = model.coef_

print(bias)
print(coeff)
# Out:
# 1.7169492241159656
# [ 0.7605872  -0.68708745]

# %% [markdown]
# ## Score

# %%
model.score(X,Y)
# Out:
# 0.8152095679916156

# %%
## Visualise

plt.scatter(X[:,0],Y,label='data')
plt.scatter(X[:,0],output,color='orange',label='prediction')
plt.legend()
plt.show()
plt.scatter(X[:,1],Y,label='data')
plt.scatter(X[:,1],output,color='orange',label='prediction')
plt.legend()
plt.show()
