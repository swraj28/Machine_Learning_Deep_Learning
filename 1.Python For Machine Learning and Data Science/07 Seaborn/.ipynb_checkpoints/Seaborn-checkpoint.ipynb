# %% [markdown]
# # Seaborn
# - seaborn is a python data visualisation libary.
# - it is built on top of matplotlib.

# %%
# %config Completer.use_jedi=False

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# plot the distribution of the data ---> like a histogram
sns.distplot(iris['petal_length'], bins= 20, kde=False)
plt.show()
# Out:
# C:\Users\SWRAJ KANT SHARMA\.conda\envs\tensorflow_env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(iris['petal_length'])
plt.show()

# %%
sns.scatterplot(x= iris['petal_length'], y = iris['petal_width'])
plt.show()

# %%
sns.scatterplot(x ='petal_length', y ='petal_width' , data= iris, hue='species')
plt.show()

# %%
sns.jointplot(x= 'petal_length', y = 'petal_width', data= iris, kind='reg')
plt.show()

# %%
sns.jointplot(x= 'sepal_length', y = 'sepal_width', data= iris, kind='reg')
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(data = iris, hue= 'species')

# %% [markdown]
# ## Categorical Plots

# %%
sns.countplot(x = 'species', data = iris)
plt.show()

# %%
iris.value_counts(['species'])
# Out:
# species
# virginica     50
# versicolor    50
# setosa        50
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x = 'species', y = 'petal_length', data = iris)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x = 'species', y = 'sepal_length', data = iris)
plt.show()

# %%
# advance form of box plot.
sns.violinplot(x = 'species', y = 'petal_length', data = iris)
plt.show()

# %% [markdown]
# ### Finding correlation

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.scatterplot(x= 'sepal_length', y= 'sepal_length', data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>

# %%
sns.heatmap(iris.corr(), cmap= "Accent", annot=True)
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix
# ...

# %% [markdown]
# ## Visualise Tips Dataset

# %%
tips = sns.load_dataset('tips')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.countplot(x = tips['sex'])
plt.show()

# %%
tips.value_counts(['sex'])
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
# out of all the days which day gets the highest amoun
# Ans - Sunday

sns.barplot(x = 'day', y = 'total_bill', data=tips, estimator=np.mean, hue = 'sex')
plt.show()

# %%
# Q - what do people prefer - lunch or dinner

sns.barplot(x = 'time', y = 'total_bill', data = tips, hue = 'day')
plt.show()

# %%
# do smoker people give more tip?
sns.barplot(x = 'smoker', y = 'tip', data = tips)
plt.show()

# %%
# it plots the regression line
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)
plt.show()

# %% [markdown]
# ## Challenge - Visualize Titanic Dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
sns.countplot(x=titanic['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
titanic.value_counts(['alive'])
# Out:
# alive
# no       549
# yes      342
# dtype: int64

# %%
sns.countplot(x=titanic['alive'])
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
sns.countplot(x="class", data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="class",hue="who",data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.catplot(x="class", hue="who", col="survived",
                data=titanic, kind="count",
                height=8, aspect=0.7);

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['sex'].value_counts()['male']
# Out:
# 577

# %%
sns.countplot(x="survived",data=titanic,hue="sex")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.displot(x="age",data=titanic,hue="survived",bins=20,height=10)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x = 'class', y = 'fare', data=titanic, estimator=np.mean)
plt.title("Average Fare of Each Class")
plt.show()

# %%
sns.countplot(x="survived",data=titanic,hue="who")
plt.show()

# %%
sns.barplot(x = 'embarked', y = 'fare', data=titanic, estimator=np.mean)
plt.title("Average Fare of Each Port")
plt.show()

# %%
sns.countplot(x="survived",data=titanic,hue="embarked")
plt.title("Port Embarked vs survived")
plt.show()

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(12,12))
sns.countplot(x="survived",data=titanic,hue="sibsp")
plt.title("Family Members Aboard")
plt.show()
